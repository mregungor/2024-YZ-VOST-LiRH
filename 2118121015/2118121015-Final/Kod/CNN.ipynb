# %%
import requests
import os

# Pexels API anahtarı
API_KEY = "ZyURjErxkYlpbVNnj486OtdgBXvPoi0t91Hl1dceRYVSZ4c8yFQ32Ljt"

# İndirilecek resim kategorisi
search_query = "4k wallpaper"

# İndirilecek resim sayısı
num_images = 200

# API çağrısı yaparak resimleri indirme
def download_images(api_key, query, num_images):
    url = f"https://api.pexels.com/v1/search?query={query}&per_page={num_images}"
    headers = {"Authorization": api_key}
    response = requests.get(url, headers=headers)
    data = response.json()
    photos = data["photos"] if "photos" in data else []

    # Resimleri indirme ve kaydetme
    save_dir = "dataset"  # Resimlerin kaydedileceği klasör
    os.makedirs(save_dir, exist_ok=True)
    for idx, photo in enumerate(photos):
        photo_url = photo["src"]["large"]
        filename = f"{save_dir}/image_{idx+1}.jpg"
        img_data = requests.get(photo_url).content
        with open(filename, "wb") as f:
            f.write(img_data)
        print(f"Image {idx+1}/{num_images} downloaded and saved as {filename}")

# Resimleri indirme işlemini başlatma
download_images(API_KEY, search_query, num_images)
# Out:
# Image 1/200 downloaded and saved as dataset/image_1.jpg
# Image 2/200 downloaded and saved as dataset/image_2.jpg
# Image 3/200 downloaded and saved as dataset/image_3.jpg
# Image 4/200 downloaded and saved as dataset/image_4.jpg
# Image 5/200 downloaded and saved as dataset/image_5.jpg
# Image 6/200 downloaded and saved as dataset/image_6.jpg
# Image 7/200 downloaded and saved as dataset/image_7.jpg
# Image 8/200 downloaded and saved as dataset/image_8.jpg
# Image 9/200 downloaded and saved as dataset/image_9.jpg
# Image 10/200 downloaded and saved as dataset/image_10.jpg
# Image 11/200 downloaded and saved as dataset/image_11.jpg
# Image 12/200 downloaded and saved as dataset/image_12.jpg
# Image 13/200 downloaded and saved as dataset/image_13.jpg
# Image 14/200 downloaded and saved as dataset/image_14.jpg
# Image 15/200 downloaded and saved as dataset/image_15.jpg
# Image 16/200 downloaded and saved as dataset/image_16.jpg
# Image 17/200 downloaded and saved as dataset/image_17.jpg
# Image 18/200 downloaded and saved as dataset/image_18.jpg
# Image 19/200 downloaded and saved as dataset/image_19.jpg
# Image 20/200 downloaded and saved as dataset/image_20.jpg
# Image 21/200 downloaded and saved as dataset/image_21.jpg
# Image 22/200 downloaded and saved as dataset/image_22.jpg
# Image 23/200 downloaded and saved as dataset/image_23.jpg
# Image 24/200 downloaded and saved as dataset/image_24.jpg
# Image 25/200 downloaded and saved as dataset/image_25.jpg
# Image 26/200 downloaded and saved as dataset/image_26.jpg
# Image 27/200 downloaded and saved as dataset/image_27.jpg
# Image 28/200 downloaded and saved as dataset/image_28.jpg
# Image 29/200 downloaded and saved as dataset/image_29.jpg
# Image 30/200 downloaded and saved as dataset/image_30.jpg
# Image 31/200 downloaded and saved as dataset/image_31.jpg
# Image 32/200 downloaded and saved as dataset/image_32.jpg
# Image 33/200 downloaded and saved as dataset/image_33.jpg
# Image 34/200 downloaded and saved as dataset/image_34.jpg
# Image 35/200 downloaded and saved as dataset/image_35.jpg
# Image 36/200 downloaded and saved as dataset/image_36.jpg
# Image 37/200 downloaded and saved as dataset/image_37.jpg
# Image 38/200 downloaded and saved as dataset/image_38.jpg
# Image 39/200 downloaded and saved as dataset/image_39.jpg
# Image 40/200 downloaded and saved as dataset/image_40.jpg
# Image 41/200 downloaded and saved as dataset/image_41.jpg
# Image 42/200 downloaded and saved as dataset/image_42.jpg
# Image 43/200 downloaded and saved as dataset/image_43.jpg
# Image 44/200 downloaded and saved as dataset/image_44.jpg
# Image 45/200 downloaded and saved as dataset/image_45.jpg
# Image 46/200 downloaded and saved as dataset/image_46.jpg
# Image 47/200 downloaded and saved as dataset/image_47.jpg
# Image 48/200 downloaded and saved as dataset/image_48.jpg
# Image 49/200 downloaded and saved as dataset/image_49.jpg
# Image 50/200 downloaded and saved as dataset/image_50.jpg
# Image 51/200 downloaded and saved as dataset/image_51.jpg
# Image 52/200 downloaded and saved as dataset/image_52.jpg
# Image 53/200 downloaded and saved as dataset/image_53.jpg
# Image 54/200 downloaded and saved as dataset/image_54.jpg
# Image 55/200 downloaded and saved as dataset/image_55.jpg
# Image 56/200 downloaded and saved as dataset/image_56.jpg
# Image 57/200 downloaded and saved as dataset/image_57.jpg
# Image 58/200 downloaded and saved as dataset/image_58.jpg
# Image 59/200 downloaded and saved as dataset/image_59.jpg
# Image 60/200 downloaded and saved as dataset/image_60.jpg
# Image 61/200 downloaded and saved as dataset/image_61.jpg
# Image 62/200 downloaded and saved as dataset/image_62.jpg
# Image 63/200 downloaded and saved as dataset/image_63.jpg
# Image 64/200 downloaded and saved as dataset/image_64.jpg
# Image 65/200 downloaded and saved as dataset/image_65.jpg
# Image 66/200 downloaded and saved as dataset/image_66.jpg
# Image 67/200 downloaded and saved as dataset/image_67.jpg
# Image 68/200 downloaded and saved as dataset/image_68.jpg
# Image 69/200 downloaded and saved as dataset/image_69.jpg
# Image 70/200 downloaded and saved as dataset/image_70.jpg
# Image 71/200 downloaded and saved as dataset/image_71.jpg
# Image 72/200 downloaded and saved as dataset/image_72.jpg
# Image 73/200 downloaded and saved as dataset/image_73.jpg
# Image 74/200 downloaded and saved as dataset/image_74.jpg
# Image 75/200 downloaded and saved as dataset/image_75.jpg
# Image 76/200 downloaded and saved as dataset/image_76.jpg
# Image 77/200 downloaded and saved as dataset/image_77.jpg
# Image 78/200 downloaded and saved as dataset/image_78.jpg
# Image 79/200 downloaded and saved as dataset/image_79.jpg
# Image 80/200 downloaded and saved as dataset/image_80.jpg

# %% [markdown]
# ZyURjErxkYlpbVNnj486OtdgBXvPoi0t91Hl1dceRYVSZ4c8yFQ32Ljt

# %%
import requests
import os

# Pexels API anahtarınız
API_KEY = "ZyURjErxkYlpbVNnj486OtdgBXvPoi0t91Hl1dceRYVSZ4c8yFQ32Ljt"

# İndirilecek resim kategorisi
search_query = "Masaüstü Arka Planları Fotoğrafları"

# İndirilecek resim sayısı
num_images = 200  # İsteğe bağlı, istediğiniz sayıda resmi indirebilirsiniz

# Başlangıç dosya numarası
start_number = 81

# API çağrısı yaparak resimleri indirme
def download_images(api_key, query, num_images, start_number):
    url = f"https://api.pexels.com/v1/search?query={query}&per_page={num_images}"
    headers = {"Authorization": api_key}
    response = requests.get(url, headers=headers)
    data = response.json()
    photos = data["photos"] if "photos" in data else []

    # Resimleri indirme ve kaydetme
    save_dir = "dataset"  # Resimlerin kaydedileceği klasör
    os.makedirs(save_dir, exist_ok=True)
    for idx, photo in enumerate(photos):
        photo_url = photo["src"]["large"]
        filename = f"{save_dir}/image_{start_number + idx}.jpg"
        img_data = requests.get(photo_url).content
        with open(filename, "wb") as f:
            f.write(img_data)
        print(f"Image {idx+1}/{num_images} downloaded and saved as {filename}")

# Resimleri indirme işlemini başlat
download_images(API_KEY, search_query, num_images, start_number)
# Out:
# Image 1/200 downloaded and saved as dataset/image_81.jpg
# Image 2/200 downloaded and saved as dataset/image_82.jpg
# Image 3/200 downloaded and saved as dataset/image_83.jpg
# Image 4/200 downloaded and saved as dataset/image_84.jpg
# Image 5/200 downloaded and saved as dataset/image_85.jpg
# Image 6/200 downloaded and saved as dataset/image_86.jpg
# Image 7/200 downloaded and saved as dataset/image_87.jpg
# Image 8/200 downloaded and saved as dataset/image_88.jpg
# Image 9/200 downloaded and saved as dataset/image_89.jpg
# Image 10/200 downloaded and saved as dataset/image_90.jpg
# Image 11/200 downloaded and saved as dataset/image_91.jpg
# Image 12/200 downloaded and saved as dataset/image_92.jpg
# Image 13/200 downloaded and saved as dataset/image_93.jpg
# Image 14/200 downloaded and saved as dataset/image_94.jpg
# Image 15/200 downloaded and saved as dataset/image_95.jpg
# Image 16/200 downloaded and saved as dataset/image_96.jpg
# Image 17/200 downloaded and saved as dataset/image_97.jpg
# Image 18/200 downloaded and saved as dataset/image_98.jpg
# Image 19/200 downloaded and saved as dataset/image_99.jpg
# Image 20/200 downloaded and saved as dataset/image_100.jpg
# Image 21/200 downloaded and saved as dataset/image_101.jpg
# Image 22/200 downloaded and saved as dataset/image_102.jpg
# Image 23/200 downloaded and saved as dataset/image_103.jpg
# Image 24/200 downloaded and saved as dataset/image_104.jpg
# Image 25/200 downloaded and saved as dataset/image_105.jpg
# Image 26/200 downloaded and saved as dataset/image_106.jpg
# Image 27/200 downloaded and saved as dataset/image_107.jpg
# Image 28/200 downloaded and saved as dataset/image_108.jpg
# Image 29/200 downloaded and saved as dataset/image_109.jpg

# %%
import requests
import os

# Pexels API anahtarınız
API_KEY = "ZyURjErxkYlpbVNnj486OtdgBXvPoi0t91Hl1dceRYVSZ4c8yFQ32Ljt"

# İndirilecek resim kategorisi
search_query = "Doğa Fotoğrafları"

# İndirilecek resim sayısı
num_images = 200  # İsteğe bağlı, istediğiniz sayıda resmi indirebilirsiniz

# Başlangıç dosya numarası
start_number = 110

# API çağrısı yaparak resimleri indirme
def download_images(api_key, query, num_images, start_number):
    url = f"https://api.pexels.com/v1/search?query={query}&per_page={num_images}"
    headers = {"Authorization": api_key}
    response = requests.get(url, headers=headers)
    data = response.json()
    photos = data["photos"] if "photos" in data else []

    # Resimleri indirme ve kaydetme
    save_dir = "dataset"  # Resimlerin kaydedileceği klasör
    os.makedirs(save_dir, exist_ok=True)
    for idx, photo in enumerate(photos):
        photo_url = photo["src"]["large"]
        filename = f"{save_dir}/image_{start_number + idx}.jpg"
        img_data = requests.get(photo_url).content
        with open(filename, "wb") as f:
            f.write(img_data)
        print(f"Image {idx+1}/{num_images} downloaded and saved as {filename}")

# Resimleri indirme işlemini başlat
download_images(API_KEY, search_query, num_images, start_number)
# Out:
# Image 1/200 downloaded and saved as dataset/image_110.jpg
# Image 2/200 downloaded and saved as dataset/image_111.jpg
# Image 3/200 downloaded and saved as dataset/image_112.jpg
# Image 4/200 downloaded and saved as dataset/image_113.jpg
# Image 5/200 downloaded and saved as dataset/image_114.jpg
# Image 6/200 downloaded and saved as dataset/image_115.jpg
# Image 7/200 downloaded and saved as dataset/image_116.jpg
# Image 8/200 downloaded and saved as dataset/image_117.jpg
# Image 9/200 downloaded and saved as dataset/image_118.jpg
# Image 10/200 downloaded and saved as dataset/image_119.jpg
# Image 11/200 downloaded and saved as dataset/image_120.jpg
# Image 12/200 downloaded and saved as dataset/image_121.jpg
# Image 13/200 downloaded and saved as dataset/image_122.jpg
# Image 14/200 downloaded and saved as dataset/image_123.jpg
# Image 15/200 downloaded and saved as dataset/image_124.jpg
# Image 16/200 downloaded and saved as dataset/image_125.jpg
# Image 17/200 downloaded and saved as dataset/image_126.jpg
# Image 18/200 downloaded and saved as dataset/image_127.jpg
# Image 19/200 downloaded and saved as dataset/image_128.jpg
# Image 20/200 downloaded and saved as dataset/image_129.jpg
# Image 21/200 downloaded and saved as dataset/image_130.jpg
# Image 22/200 downloaded and saved as dataset/image_131.jpg
# Image 23/200 downloaded and saved as dataset/image_132.jpg
# Image 24/200 downloaded and saved as dataset/image_133.jpg
# Image 25/200 downloaded and saved as dataset/image_134.jpg
# Image 26/200 downloaded and saved as dataset/image_135.jpg
# Image 27/200 downloaded and saved as dataset/image_136.jpg
# Image 28/200 downloaded and saved as dataset/image_137.jpg
# Image 29/200 downloaded and saved as dataset/image_138.jpg
# Image 30/200 downloaded and saved as dataset/image_139.jpg
# Image 31/200 downloaded and saved as dataset/image_140.jpg
# Image 32/200 downloaded and saved as dataset/image_141.jpg
# Image 33/200 downloaded and saved as dataset/image_142.jpg
# Image 34/200 downloaded and saved as dataset/image_143.jpg
# Image 35/200 downloaded and saved as dataset/image_144.jpg
# Image 36/200 downloaded and saved as dataset/image_145.jpg
# Image 37/200 downloaded and saved as dataset/image_146.jpg
# Image 38/200 downloaded and saved as dataset/image_147.jpg
# Image 39/200 downloaded and saved as dataset/image_148.jpg
# Image 40/200 downloaded and saved as dataset/image_149.jpg
# Image 41/200 downloaded and saved as dataset/image_150.jpg
# Image 42/200 downloaded and saved as dataset/image_151.jpg
# Image 43/200 downloaded and saved as dataset/image_152.jpg
# Image 44/200 downloaded and saved as dataset/image_153.jpg

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, metrics
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Drive'ı bağlama
drive.mount('/content/drive')

# Görüntü konumu
image_dir = '/content/dataset/'
test_image_path = '/content/drive/My Drive/DataSet/test4.png'

# Görüntüleri yükleme ve boyutlarını ayarlama
def load_and_preprocess_images(image_dir, image_size=(512, 512)):
    images = []
    for filename in os.listdir(image_dir):
        if filename.endswith('.jpg') or filename.endswith('.jpeg') or filename.endswith('.png'):
            image_path = os.path.join(image_dir, filename)
            img = tf.keras.preprocessing.image.load_img(image_path, target_size=image_size)
            img_array = tf.keras.preprocessing.image.img_to_array(img)
            img_array = img_array.astype('float32') / 255.0  # Normalizasyon
            images.append(img_array)
    return np.array(images)

# Gaussian Bulanıklığı Gürültüsü Ekleme Fonksiyonu
def add_gaussian_noise(images, noise_std=0.1):
    noisy_images = images + np.random.normal(0, noise_std, size=images.shape)
    return np.clip(noisy_images, 0., 1.)

# Salt-and-Pepper Noise Ekleme Fonksiyonu
def add_salt_and_pepper_noise(images, noise_level=0.1):
    noisy_images = np.copy(images)
    num_salt_pixels = np.ceil(noise_level * images.size * 0.5)
    salt_coords = [np.random.randint(0, i - 1, int(num_salt_pixels)) for i in images.shape]
    pepper_coords = [np.random.randint(0, i - 1, int(num_salt_pixels)) for i in images.shape]
    noisy_images[salt_coords[0], salt_coords[1], salt_coords[2]] = 1
    noisy_images[pepper_coords[0], pepper_coords[1], pepper_coords[2]] = 0
    return noisy_images

# Gaussian ve Salt-and-Pepper Gürültüsü Ekleme
def add_noise(images, gaussian_std=0.1, salt_pepper_level=0.1):
    noisy_images = add_gaussian_noise(images, gaussian_std)
    noisy_images = add_salt_and_pepper_noise(noisy_images, salt_pepper_level)
    return noisy_images

# Görüntüleri yükle ve boyutlarını ayarla
images = load_and_preprocess_images(image_dir)
images_noisy = add_noise(images, gaussian_std=0.1, salt_pepper_level=0.1)

# DnCNN Modeli Oluşturma ve Eğitim
def build_dncnn_model():
    model = models.Sequential()
    model.add(layers.Conv2D(128, (3, 3), padding='same', input_shape=(512, 512, 3)))
    model.add(layers.LeakyReLU(alpha=0.1))

    model.add(layers.Conv2D(128, (3, 3), padding='same'))
    model.add(layers.LeakyReLU(alpha=0.1))

    model.add(layers.Conv2D(128, (3, 3), padding='same'))
    model.add(layers.LeakyReLU(alpha=0.1))

    model.add(layers.Conv2D(3, (3, 3), padding='same'))

    return model

model = build_dncnn_model()
model.summary()

optimizer = optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=[metrics.MeanSquaredError()])

epochs = 80
batch_size = 3

history = model.fit(images_noisy, images, epochs=epochs, batch_size=batch_size, validation_split=0.2)

# Eğitim ve Doğrulama Kayıp Grafiği
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Test Aşaması
# test1 görselini yükle
test_img = tf.keras.preprocessing.image.load_img(test_image_path, target_size=(512, 512))
test_img_array = tf.keras.preprocessing.image.img_to_array(test_img)
test_img_array = test_img_array.astype('float32') / 255.0  # Normalizasyon

# Model ile denoising yap
denoised_test_image = model.predict(np.expand_dims(test_img_array, axis=0))

# Sonuçları Görselleştirme
plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(test_img_array)
plt.title('Original')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(denoised_test_image[0])
plt.title('Denoised')
plt.axis('off')

plt.show()

# Doğruluk Hesaplama
def calculate_accuracy(test_img_array, denoised_test_image, threshold=0.1):
    accurate_pixels = np.sum(np.abs(test_img_array - denoised_test_image) < threshold)
    total_pixels = test_img_array.size
    accuracy = accurate_pixels / total_pixels
    return accuracy

threshold = 0.1  # Eşik değeri
accuracy = calculate_accuracy(images, model.predict(images_noisy), threshold)
print(f"Model doğruluğu: {accuracy * 100:.2f}%")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_53 (Conv2D)          (None, 512, 512, 128)     3584
#
#  leaky_re_lu_40 (LeakyReLU)  (None, 512, 512, 128)     0
#
#  conv2d_54 (Conv2D)          (None, 512, 512, 128)     147584
#
#  leaky_re_lu_41 (LeakyReLU)  (None, 512, 512, 128)     0
#
#  conv2d_55 (Conv2D)          (None, 512, 512, 128)     147584
#
#  leaky_re_lu_42 (LeakyReLU)  (None, 512, 512, 128)     0
#
#  conv2d_56 (Conv2D)          (None, 512, 512, 3)       3459
#
# =================================================================
# Total params: 302211 (1.15 MB)
# Trainable params: 302211 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/80
# 41/41 [==============================] - 3s 55ms/step - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 2/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 3/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 4/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 5/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 6/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 7/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 8/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 9/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 10/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 11/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 12/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 13/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 14/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 15/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 16/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 17/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 18/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 19/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 20/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 21/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 22/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 23/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 24/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 25/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 26/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 27/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 28/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 29/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 30/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 31/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 32/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 33/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 34/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 35/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 36/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 37/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 38/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 39/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 40/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 41/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 42/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 43/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 44/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 45/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 46/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 47/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 48/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 49/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 50/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 51/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 52/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 53/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 54/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 55/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 56/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 57/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 58/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 59/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 60/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 61/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 62/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 63/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 64/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 65/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 66/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 67/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 68/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 69/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 70/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 71/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 72/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 73/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 74/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 75/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 76/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 77/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 78/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 79/80
# 41/41 [==============================] - 2s 45ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 80/80
# 41/41 [==============================] - 2s 44ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# 1/1 [==============================] - 0s 63ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 5/5 [==============================] - 1s 144ms/step
# Model doğruluğu: 95.90%
