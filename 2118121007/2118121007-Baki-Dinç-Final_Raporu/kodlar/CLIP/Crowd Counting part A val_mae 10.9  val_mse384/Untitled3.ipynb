# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split
from tqdm import tqdm

from numpy.random import seed
seed(1)
from tensorflow.random import set_seed
set_seed(1)

import scipy
from scipy import spatial
from scipy import ndimage

import tensorflow as tf
import keras
from keras.layers import Conv2D, Average, MaxPooling2D, Flatten,concatenate, Input, Dense, UpSampling2D, Conv2DTranspose, ReLU, Activation, BatchNormalization,Lambda
from keras.models import Model
from keras.losses import mean_squared_error
from keras.losses import mean_absolute_percentage_error
from keras.optimizers import Adam, Nadam
from keras.applications import vgg16
import keras.backend as K

# %%
# !pip install PyDrive
# Out:
# Collecting PyDrive
#   Downloading PyDrive-1.3.1.tar.gz (987 kB)
#      ---------------------------------------- 0.0/987.4 kB ? eta -:--:--
#      ---------------------------------------- 10.2/987.4 kB ? eta -:--:--
#      - ----------------------------------- 30.7/987.4 kB 435.7 kB/s eta 0:00:03
#      - ----------------------------------- 41.0/987.4 kB 393.8 kB/s eta 0:00:03
#      --- --------------------------------- 92.2/987.4 kB 655.4 kB/s eta 0:00:02
#      ----- ------------------------------ 143.4/987.4 kB 847.9 kB/s eta 0:00:01
#      -------- ----------------------------- 225.3/987.4 kB 1.1 MB/s eta 0:00:01
#      ------------ ------------------------- 317.4/987.4 kB 1.3 MB/s eta 0:00:01
#      ------------------ ------------------- 471.0/987.4 kB 1.7 MB/s eta 0:00:01
#      ----------------------- -------------- 614.4/987.4 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------  972.8/987.4 kB 2.8 MB/s eta 0:00:01
#      -------------------------------------- 987.4/987.4 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting google-api-python-client>=1.2 (from PyDrive)
#   Downloading google_api_python_client-2.129.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting oauth2client>=4.0.0 (from PyDrive)
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: PyYAML>=3.0 in c:\users\bakid\anaconda3\lib\site-packages (from PyDrive) (6.0.1)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client>=1.2->PyDrive)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 (from google-api-python-client>=1.2->PyDrive)
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client>=1.2->PyDrive)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client>=1.2->PyDrive)
#   Downloading google_api_core-2.19.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.2->PyDrive)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\bakid\anaconda3\lib\site-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\bakid\anaconda3\lib\site-packages (from oauth2client>=4.0.0->PyDrive) (0.2.8)
# Collecting rsa>=3.1.4 (from oauth2client>=4.0.0->PyDrive)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: six>=1.6.1 in c:\users\bakid\anaconda3\lib\site-packages (from oauth2client>=4.0.0->PyDrive) (1.16.0)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive)
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\bakid\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (3.20.3)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive)
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\bakid\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bakid\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=1.2->PyDrive) (4.2.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\bakid\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.2->PyDrive) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bakid\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bakid\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bakid\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bakid\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2024.2.2)
# Downloading google_api_python_client-2.129.0-py2.py3-none-any.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.9/11.6 MB 27.4 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/11.6 MB 32.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.6/11.6 MB 14.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.5/11.6 MB 17.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/11.6 MB 19.9 MB/s eta 0:00:01
#    ------------- -------------------------- 3.9/11.6 MB 19.0 MB/s eta 0:00:01
#    --------------- ------------------------ 4.6/11.6 MB 18.5 MB/s eta 0:00:01
#    ------------------- -------------------- 5.6/11.6 MB 19.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.5/11.6 MB 20.9 MB/s eta 0:00:01
#    ------------------------- -------------- 7.5/11.6 MB 21.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.5/11.6 MB 21.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.5/11.6 MB 22.4 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.6 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 24.3 MB/s eta 0:00:00
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.2 kB ? eta -:--:--
#    ---------------------------------------- 98.2/98.2 kB 5.9 MB/s eta 0:00:00
# Downloading google_api_core-2.19.0-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.0 kB ? eta -:--:--
#    ---------------------------------------- 139.0/139.0 kB ? eta 0:00:00
# Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#    ---------------------------------------- 0.0/189.2 kB ? eta -:--:--
#    ---------------------------------------- 189.2/189.2 kB ? eta 0:00:00
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#    ---------------------------------------- 96.9/96.9 kB ? eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#    ---------------------------------------- 0.0/229.1 kB ? eta -:--:--
#    ---------------------------------------- 229.1/229.1 kB ? eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#    ---------------------------------------- 48.8/48.8 kB ? eta 0:00:00
# Building wheels for collected packages: PyDrive
#   Building wheel for PyDrive (setup.py): started
#   Building wheel for PyDrive (setup.py): finished with status 'done'
#   Created wheel for PyDrive: filename=PyDrive-1.3.1-py3-none-any.whl size=27465 sha256=9e9aff3823d3a3b44bda6ec0c8e20bf283a70a3918b354560438b1bbd1e94df0
#   Stored in directory: c:\users\bakid\appdata\local\pip\cache\wheels\31\d5\09\88865e0059104686eb8365ca1d36a8b27deef34232c3b62c90
# Successfully built PyDrive
# Installing collected packages: uritemplate, rsa, proto-plus, httplib2, googleapis-common-protos, oauth2client, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, PyDrive
# Successfully installed PyDrive-1.3.1 google-api-core-2.19.0 google-api-python-client-2.129.0 google-auth-2.29.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.63.0 httplib2-0.22.0 oauth2client-4.1.3 proto-plus-1.23.0 rsa-4.9 uritemplate-4.1.1
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\bakiD\anaconda3\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 from pydrive.auth import GoogleAuth
#       2 from pydrive.drive import GoogleDrive
# ----> 3 from google.colab import auth
#       4 from oauth2client.client import GoogleCredentials
#       6 auth.authenticate_user()
#
# ModuleNotFoundError: No module named 'google.colab'
